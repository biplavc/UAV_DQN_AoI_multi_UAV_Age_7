# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from networkx import *
import random
from scipy.spatial.distance import pdist, squareform
from networkx.algorithms.approximation import min_weighted_dominating_set
from itertools import product  
# from age_calculation import *

# from networkx.algorithms.approximation import dominating_set
from parameters import *
# from create_graph_1 import *
from itertools import combinations
import pickle

# %matplotlib inline

# %%
def running_mean(x): #, N = 5):
    N = 100
    cumsum = np.cumsum(np.insert(x, 0, 0)) 
    return (cumsum[N:] - cumsum[:-N]) / float(N)

# %% [markdown]
# ### exp 9,10 and 11 - 10 users and varying UAVs - [10], [5,5], [3,3,4]

# %%
# exp 9
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp9/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_10U_final = pickle.load(open(path_RP + "10U_dqn_overall.pickle", "rb"))
MAD_10U_final = pickle.load(open(path_RP + "10U_mad_overall.pickle", "rb"))
random_10U_final = pickle.load(open(path_RP + "10U_random_overall.pickle", "rb"))
greedy_10U_final = pickle.load(open(path_RP + "10U_greedy_overall.pickle", "rb"))


# dqn_10U_final = dqn_10U_final[10]
# MAD_mean_10 = np.mean(MAD_10U_final[10])
# random_mean_10_min = np.mean(random_10U_final[10])
# random_mean_10_max = np.max(random_10U_final[10])
# greedy_mean_10 = np.mean(greedy_10U_final[10])
# random_mean_10 = np.mean(random_10U_final[10])

exp9_mad     = np.mean(MAD_10U_final[10])
exp9_dqn     = -np.mean(dqn_10U_final[10][-5:])
exp9_greedy  = np.mean(greedy_10U_final[10])
exp9_random  = np.mean(random_10U_final[10])



############################################################
# exp 10
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp10/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_10U_final = pickle.load(open(path_RP + "10U_dqn_overall.pickle", "rb"))
MAD_10U_final = pickle.load(open(path_RP + "10U_mad_overall.pickle", "rb"))
random_10U_final = pickle.load(open(path_RP + "10U_random_overall.pickle", "rb"))
greedy_10U_final = pickle.load(open(path_RP + "10U_greedy_overall.pickle", "rb"))


# dqn_10U_final = dqn_10U_final[10]
# MAD_mean_10 = np.mean(MAD_10U_final[10])
# random_mean_10_min = np.mean(random_10U_final[10])
# random_mean_10_max = np.max(random_10U_final[10])
# greedy_mean_10 = np.mean(greedy_10U_final[10])
# random_mean_10 = np.mean(random_10U_final[10])

exp10_mad     = np.mean(MAD_10U_final[10])
exp10_dqn     = -np.mean(dqn_10U_final[10][-5:])
exp10_greedy  = np.mean(greedy_10U_final[10])
exp10_random  = np.mean(random_10U_final[10])

############################################################

# exp 11
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp11/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_10U_final = pickle.load(open(path_RP + "10U_dqn_overall.pickle", "rb"))
MAD_10U_final = pickle.load(open(path_RP + "10U_mad_overall.pickle", "rb"))
random_10U_final = pickle.load(open(path_RP + "10U_random_overall.pickle", "rb"))
greedy_10U_final = pickle.load(open(path_RP + "10U_greedy_overall.pickle", "rb"))


# dqn_10U_final = dqn_10U_final[10])
# MAD_mean_10 = np.mean(MAD_10U_final[10])
# random_mean_10_min = np.mean(random_10U_final[10])
# random_mean_10_max = np.max(random_10U_final[10])
# greedy_mean_10 = np.mean(greedy_10U_final[10])
# random_mean_10 = np.mean(random_10U_final[10])

exp11_mad     = np.mean(MAD_10U_final[10])
exp11_dqn     = -np.mean(dqn_10U_final[10][-5:])
exp11_greedy  = np.mean(greedy_10U_final[10])
exp11_random  = np.mean(random_10U_final[10])

############################################################


## plot as bar plots

fig, ax = plt.subplots()
barWidth = 0.15
 
dqn =    [ exp9_dqn/10 ,   exp10_dqn/10,    exp11_dqn/10] # 100, 150, 200, 250
MAD =    [ exp9_mad/10 ,   exp10_mad/10,    exp11_mad/10] # 100, 150, 200, 250
greedy = [ exp9_greedy/10 , exp10_greedy/10, exp11_greedy/10] # 100, 150, 200, 250
random = [ exp9_random/10 , exp10_random/10, exp11_random/10]
  
N = 3
ind = np.arange(N)    # the x locations for the groups
width = 0.15         # the width of the bars

p1 = ax.bar(ind, dqn, width, bottom=0)
p2 = ax.bar(ind + width, MAD, width, bottom=0)
p3 = ax.bar(ind + 2*width, greedy, width, bottom=0)
p4 = ax.bar(ind + 3*width, random, width, bottom=0)


# ax.set_title('Scalability Analysis')
ax.set_xticks(ind + 1.5*width)
ax.set_xticklabels(( 'Case 1', 'Case 2', 'Case 3')) #, '250'))
ax.tick_params(axis='x', labelsize=19)
ax.tick_params(axis='y', labelsize=19)


ax.legend((p1[0], p2[0], p3[0], p4[0]), ('DQN', 'MAD', 'greedy','random'), fontsize=20, loc='lower right')
# plt.xlabel('Cases', fontsize=22)
plt.ylabel('Mean AoI at BS', fontsize=20)
plt.grid('True')

## /home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp9

# %% [markdown]
# ### exp 14,15 and 16 - 3 UAVs users and varying users - (1,1,1), (2,2,2), (3,3,3)

# %%
# exp 14
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp14/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_3U_final = pickle.load(open(path_RP + "3U_dqn_overall.pickle", "rb"))
MAD_3U_final = pickle.load(open(path_RP + "3U_mad_overall.pickle", "rb"))
random_3U_final = pickle.load(open(path_RP + "3U_random_overall.pickle", "rb"))
greedy_3U_final = pickle.load(open(path_RP + "3U_greedy_overall.pickle", "rb"))


# dqn_10U_final = dqn_10U_final[10]
# MAD_mean_10 = np.mean(MAD_10U_final[10])
# random_mean_10_min = np.mean(random_10U_final[10])
# random_mean_10_max = np.max(random_10U_final[10])
# greedy_mean_10 = np.mean(greedy_10U_final[10])
# random_mean_10 = np.mean(random_10U_final[10])

exp14_mad     = np.mean(MAD_3U_final[3])
exp14_dqn     = -np.mean(dqn_3U_final[3][-5:])
exp14_greedy  = np.mean(greedy_3U_final[3])
exp14_random  = np.mean(random_3U_final[3])



############################################################
# exp 15
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp15/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_6U_final = pickle.load(open(path_RP + "6U_dqn_overall.pickle", "rb"))
MAD_6U_final = pickle.load(open(path_RP + "6U_mad_overall.pickle", "rb"))
random_6U_final = pickle.load(open(path_RP + "6U_random_overall.pickle", "rb"))
greedy_6U_final = pickle.load(open(path_RP + "6U_greedy_overall.pickle", "rb"))


# dqn_10U_final = dqn_10U_final[10]
# MAD_mean_10 = np.mean(MAD_10U_final[10])
# random_mean_10_min = np.mean(random_10U_final[10])
# random_mean_10_max = np.max(random_10U_final[10])
# greedy_mean_10 = np.mean(greedy_10U_final[10])
# random_mean_10 = np.mean(random_10U_final[10])

exp15_mad     = np.mean(MAD_6U_final[6])
exp15_dqn     = -np.mean(dqn_6U_final[6][-5:])
exp15_greedy  = np.mean(greedy_6U_final[6])
exp15_random  = np.mean(random_6U_final[6])

############################################################

# exp 16
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp16/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_9U_final = pickle.load(open(path_RP + "9U_dqn_overall.pickle", "rb"))
MAD_9U_final = pickle.load(open(path_RP + "9U_mad_overall.pickle", "rb"))
random_9U_final = pickle.load(open(path_RP + "9U_random_overall.pickle", "rb"))
greedy_9U_final = pickle.load(open(path_RP + "9U_greedy_overall.pickle", "rb"))


# dqn_10U_final = dqn_10U_final[10])
# MAD_mean_10 = np.mean(MAD_10U_final[10])
# random_mean_10_min = np.mean(random_10U_final[10])
# random_mean_10_max = np.max(random_10U_final[10])
# greedy_mean_10 = np.mean(greedy_10U_final[10])
# random_mean_10 = np.mean(random_10U_final[10])

exp16_mad     = np.mean(MAD_9U_final[9])
exp16_dqn     = -np.mean(dqn_9U_final[9][-5:])
exp16_greedy  = np.mean(greedy_9U_final[9])
exp16_random  = np.mean(random_9U_final[9])

############################################################


## plot as bar plots

fig, ax = plt.subplots()
barWidth = 0.15
 
dqn =    [ exp14_dqn/3 ,   exp15_dqn/6,    exp16_dqn/9] # 100, 150, 200, 250
MAD =    [ exp14_mad/3 ,   exp15_mad/6,    exp16_mad/9] # 100, 150, 200, 250
greedy = [ exp14_greedy/3, exp15_greedy/6, exp16_greedy/9] # 100, 150, 200, 250
random = [ exp14_random/3, exp15_random/6, exp16_random/9]
  
N = 3
ind = np.arange(N)    # the x locations for the groups
width = 0.15         # the width of the bars

p1 = ax.bar(ind, dqn, width, bottom=0)
p2 = ax.bar(ind + width, MAD, width, bottom=0)
p3 = ax.bar(ind + 2*width, greedy, width, bottom=0)
p4 = ax.bar(ind + 3*width, random, width, bottom=0)


# ax.set_title('Scalability Analysis')
ax.set_xticks(ind + 1.5*width)
ax.set_xticklabels(( 'Case 1', 'Case 2', 'Case 3')) #, '250'))
ax.tick_params(axis='x', labelsize=19)
ax.tick_params(axis='y', labelsize=19)


ax.legend((p1[0], p2[0], p3[0], p4[0]), ('DQN', 'MAD', 'greedy','random'), fontsize=20, loc='lower right')
# ax.legend(loc='best')
# plt.xlabel('Cases', fontsize=22)
plt.ylabel('Mean AoI at BS', fontsize=20)
plt.grid('True')

## /home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp9

# %% [markdown]
# ### exp 19,20 and 21 - 3 UAVs users and 9 users - (3,3,3) - K=1  L=1,K=1 L=2,K=1 L=3

# %%
# exp 19
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp19/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_9U_final = pickle.load(open(path_RP + "9U_dqn_overall.pickle", "rb"))
MAD_9U_final = pickle.load(open(path_RP + "9U_mad_overall.pickle", "rb"))
random_9U_final = pickle.load(open(path_RP + "9U_random_overall.pickle", "rb"))
greedy_9U_final = pickle.load(open(path_RP + "9U_greedy_overall.pickle", "rb"))


# dqn_10U_final = dqn_10U_final[10]
# MAD_mean_10 = np.mean(MAD_10U_final[10])
# random_mean_10_min = np.mean(random_10U_final[10])
# random_mean_10_max = np.max(random_10U_final[10])
# greedy_mean_10 = np.mean(greedy_10U_final[10])
# random_mean_10 = np.mean(random_10U_final[10])

exp19_mad     = np.mean(MAD_9U_final[9])
exp19_dqn     = -np.mean(dqn_9U_final[9][-5:])
exp19_greedy  = np.mean(greedy_9U_final[9])
exp19_random  = np.mean(random_9U_final[9])



############################################################
# exp 20
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp20/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_9U_final = pickle.load(open(path_RP + "9U_dqn_overall.pickle", "rb"))
MAD_9U_final = pickle.load(open(path_RP + "9U_mad_overall.pickle", "rb"))
random_9U_final = pickle.load(open(path_RP + "9U_random_overall.pickle", "rb"))
greedy_9U_final = pickle.load(open(path_RP + "9U_greedy_overall.pickle", "rb"))


# dqn_10U_final = dqn_10U_final[10]
# MAD_mean_10 = np.mean(MAD_10U_final[10])
# random_mean_10_min = np.mean(random_10U_final[10])
# random_mean_10_max = np.max(random_10U_final[10])
# greedy_mean_10 = np.mean(greedy_10U_final[10])
# random_mean_10 = np.mean(random_10U_final[10])

exp20_mad     = np.mean(MAD_9U_final[9])
exp20_dqn     = -np.mean(dqn_9U_final[9][-5:])
exp20_greedy  = np.mean(greedy_9U_final[9])
exp20_random  = np.mean(random_9U_final[9])


############################################################

# exp 21
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp21/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_9U_final = pickle.load(open(path_RP + "9U_dqn_overall.pickle", "rb"))
MAD_9U_final = pickle.load(open(path_RP + "9U_mad_overall.pickle", "rb"))
random_9U_final = pickle.load(open(path_RP + "9U_random_overall.pickle", "rb"))
greedy_9U_final = pickle.load(open(path_RP + "9U_greedy_overall.pickle", "rb"))


# dqn_10U_final = dqn_10U_final[10]
# MAD_mean_10 = np.mean(MAD_10U_final[10])
# random_mean_10_min = np.mean(random_10U_final[10])
# random_mean_10_max = np.max(random_10U_final[10])
# greedy_mean_10 = np.mean(greedy_10U_final[10])
# random_mean_10 = np.mean(random_10U_final[10])

exp21_mad     = np.mean(MAD_9U_final[9])
exp21_dqn     = -np.mean(dqn_9U_final[9][-5:])
exp21_greedy  = np.mean(greedy_9U_final[9])
exp21_random  = np.mean(random_9U_final[9])


############################################################


## plot as bar plots

fig, ax = plt.subplots()
barWidth = 0.15
 
dqn =    [ exp19_dqn/9 ,   exp20_dqn/9,    exp21_dqn/9] # 100, 150, 200, 250
MAD =    [ exp19_mad/9 ,   exp20_mad/9,    exp21_mad/9] # 100, 150, 200, 250
greedy = [ exp19_greedy/9, exp20_greedy/9, exp21_greedy/9] # 100, 150, 200, 250
random = [ exp19_random/9, exp20_random/9, exp21_random/9]
  
N = 3
ind = np.arange(N)    # the x locations for the groups
width = 0.15         # the width of the bars

p1 = ax.bar(ind, dqn, width, bottom=0)
p2 = ax.bar(ind + width, MAD, width, bottom=0)
p3 = ax.bar(ind + 2*width, greedy, width, bottom=0)
p4 = ax.bar(ind + 3*width, random, width, bottom=0)


# ax.set_title('Scalability Analysis')
ax.set_xticks(ind + 1.5*width)
ax.set_xticklabels(( 'Case 1', 'Case 2', 'Case 3')) #, '250'))
ax.tick_params(axis='x', labelsize=19)
ax.tick_params(axis='y', labelsize=19)


ax.legend((p1[0], p2[0], p3[0], p4[0]), ('DQN', 'MAD', 'greedy','random'), fontsize=20, loc='lower right')
# ax.legend(loc='best')
# plt.xlabel('Cases', fontsize=22)
plt.ylabel('Mean AoI at BS', fontsize=20)
plt.grid('True')

## /home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp9

# %% [markdown]
# ### exp 22,23 and 24 - 3 UAVs users and 9 users - (3,3,3) - K=1 L=5, K=2 L=5, K=3 L=5

# %%
# exp 22
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp22/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_9U_final = pickle.load(open(path_RP + "9U_dqn_overall.pickle", "rb"))
MAD_9U_final = pickle.load(open(path_RP + "9U_mad_overall.pickle", "rb"))
random_9U_final = pickle.load(open(path_RP + "9U_random_overall.pickle", "rb"))
greedy_9U_final = pickle.load(open(path_RP + "9U_greedy_overall.pickle", "rb"))


# dqn_10U_final = dqn_10U_final[10]
# MAD_mean_10 = np.mean(MAD_10U_final[10])
# random_mean_10_min = np.mean(random_10U_final[10])
# random_mean_10_max = np.max(random_10U_final[10])
# greedy_mean_10 = np.mean(greedy_10U_final[10])
# random_mean_10 = np.mean(random_10U_final[10])

exp22_mad     = np.mean(MAD_9U_final[9])
exp22_dqn     = -np.max(dqn_9U_final[9][-5:])
exp22_greedy  = np.mean(greedy_9U_final[9])
exp22_random  = np.mean(random_9U_final[9])



############################################################
# exp 23
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp23/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_9U_final = pickle.load(open(path_RP + "9U_dqn_overall.pickle", "rb"))
MAD_9U_final = pickle.load(open(path_RP + "9U_mad_overall.pickle", "rb"))
random_9U_final = pickle.load(open(path_RP + "9U_random_overall.pickle", "rb"))
greedy_9U_final = pickle.load(open(path_RP + "9U_greedy_overall.pickle", "rb"))


# dqn_10U_final = dqn_10U_final[10]
# MAD_mean_10 = np.mean(MAD_10U_final[10])
# random_mean_10_min = np.mean(random_10U_final[10])
# random_mean_10_max = np.max(random_10U_final[10])
# greedy_mean_10 = np.mean(greedy_10U_final[10])
# random_mean_10 = np.mean(random_10U_final[10])

exp23_mad     = np.mean(MAD_9U_final[9])
exp23_dqn     = -np.max(dqn_9U_final[9][-5:])
exp23_greedy  = np.mean(greedy_9U_final[9])
exp23_random  = np.mean(random_9U_final[9])


############################################################

# exp 24
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp24/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_9U_final = pickle.load(open(path_RP + "9U_dqn_overall.pickle", "rb"))
MAD_9U_final = pickle.load(open(path_RP + "9U_mad_overall.pickle", "rb"))
random_9U_final = pickle.load(open(path_RP + "9U_random_overall.pickle", "rb"))
greedy_9U_final = pickle.load(open(path_RP + "9U_greedy_overall.pickle", "rb"))


# dqn_10U_final = dqn_10U_final[10]
# MAD_mean_10 = np.mean(MAD_10U_final[10])
# random_mean_10_min = np.mean(random_10U_final[10])
# random_mean_10_max = np.max(random_10U_final[10])
# greedy_mean_10 = np.mean(greedy_10U_final[10])
# random_mean_10 = np.mean(random_10U_final[10])

exp24_mad     = np.mean(MAD_9U_final[9])
exp24_dqn     = -np.max(dqn_9U_final[9][-5:])
exp24_greedy  = np.mean(greedy_9U_final[9])
exp24_random  = np.mean(random_9U_final[9])

##############################################

# exp 25
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp25/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_9U_final = pickle.load(open(path_RP + "9U_dqn_overall.pickle", "rb"))
MAD_9U_final = pickle.load(open(path_RP + "9U_mad_overall.pickle", "rb"))
random_9U_final = pickle.load(open(path_RP + "9U_random_overall.pickle", "rb"))
greedy_9U_final = pickle.load(open(path_RP + "9U_greedy_overall.pickle", "rb"))


# dqn_10U_final = dqn_10U_final[10]
# MAD_mean_10 = np.mean(MAD_10U_final[10])
# random_mean_10_min = np.mean(random_10U_final[10])
# random_mean_10_max = np.max(random_10U_final[10])
# greedy_mean_10 = np.mean(greedy_10U_final[10])
# random_mean_10 = np.mean(random_10U_final[10])

exp25_mad     = np.mean(MAD_9U_final[9])
exp25_dqn     = -np.max(dqn_9U_final[9][-5:])
exp25_greedy  = np.mean(greedy_9U_final[9])
exp25_random  = np.mean(random_9U_final[9])


############################################################


## plot as bar plots

fig, ax = plt.subplots()
barWidth = 0.15
 
dqn =    [ exp22_dqn , exp23_dqn ,   exp24_dqn] # 100, 150, 200, 250
MAD =    [ exp22_mad , exp23_mad ,  exp24_mad] # 100, 150, 200, 250
greedy = [ exp22_greedy, exp23_greedy, exp24_greedy] # 100, 150, 200, 250
random = [ exp22_random, exp23_random, exp24_random]
  
N = 3
ind = np.arange(N)    # the x locations for the groups
width = 0.15         # the width of the bars

p1 = ax.bar(ind, dqn, width, bottom=0)
p2 = ax.bar(ind + width, MAD, width, bottom=0)
p3 = ax.bar(ind + 2*width, greedy, width, bottom=0)
p4 = ax.bar(ind + 3*width, random, width, bottom=0)


# ax.set_title('Scalability Analysis')
ax.set_xticks(ind + 1.5*width)
ax.set_xticklabels(( 'Case 1', 'Case 2', 'Case 3')) #, '250'))
ax.tick_params(axis='x', labelsize=19)
ax.tick_params(axis='y', labelsize=19)


ax.legend((p1[0], p2[0], p3[0], p4[0]), ('DQN', 'MAD', 'greedy','random'), fontsize=20, loc='lower right')
# ax.legend(loc='best')
# plt.xlabel('Cases', fontsize=22)
plt.ylabel('Sum AoI at BS', fontsize=20)
plt.grid('True')

## /home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp9

# %% [markdown]
# ### exp 26, 27, 28

# %%
# exp 26
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp26/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_9U_final = pickle.load(open(path_RP + "9U_dqn_overall.pickle", "rb"))
MAD_9U_final = pickle.load(open(path_RP + "9U_mad_overall.pickle", "rb"))
random_9U_final = pickle.load(open(path_RP + "9U_random_overall.pickle", "rb"))
greedy_9U_final = pickle.load(open(path_RP + "9U_greedy_overall.pickle", "rb"))


exp26_mad     = np.mean(MAD_9U_final[9])
exp26_dqn     = -np.max(dqn_9U_final[9][-5:])
exp26_greedy  = np.mean(greedy_9U_final[9])
exp26_random  = np.mean(random_9U_final[9])



############################################################
# exp 27
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp27/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_9U_final = pickle.load(open(path_RP + "9U_dqn_overall.pickle", "rb"))
MAD_9U_final = pickle.load(open(path_RP + "9U_mad_overall.pickle", "rb"))
random_9U_final = pickle.load(open(path_RP + "9U_random_overall.pickle", "rb"))
greedy_9U_final = pickle.load(open(path_RP + "9U_greedy_overall.pickle", "rb"))


exp27_mad     = np.mean(MAD_9U_final[9])
exp27_dqn     = -np.max(dqn_9U_final[9][-5:])
exp27_greedy  = np.mean(greedy_9U_final[9])
exp27_random  = np.mean(random_9U_final[9])


############################################################

# exp 28
path = "/home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp28/"
path_MDS = path + "MDS/"
path_RP = path + "RP/"


dqn_9U_final = pickle.load(open(path_RP + "9U_dqn_overall.pickle", "rb"))
MAD_9U_final = pickle.load(open(path_RP + "9U_mad_overall.pickle", "rb"))
random_9U_final = pickle.load(open(path_RP + "9U_random_overall.pickle", "rb"))
greedy_9U_final = pickle.load(open(path_RP + "9U_greedy_overall.pickle", "rb"))



exp28_mad     = np.mean(MAD_9U_final[9])
exp28_dqn     = -np.max(dqn_9U_final[9][-5:])
exp28_greedy  = np.mean(greedy_9U_final[9])
exp28_random  = np.mean(random_9U_final[9])


############################################################


## plot as bar plots

fig, ax = plt.subplots()
barWidth = 0.15
 
dqn =    [ exp26_dqn/9 , exp27_dqn/9 ,   exp28_dqn/9] # 100, 150, 200, 250
MAD =    [ exp26_mad/9 , exp27_mad/9 ,  exp28_mad/9] # 100, 150, 200, 250
greedy = [ exp26_greedy/9, exp27_greedy/9, exp28_greedy/9] # 100, 150, 200, 250
random = [ exp26_random/9, exp27_random/9, exp28_random/9]
  
N = 3
ind = np.arange(N)    # the x locations for the groups
width = 0.15         # the width of the bars

p1 = ax.bar(ind, dqn, width, bottom=0)
p2 = ax.bar(ind + width, MAD, width, bottom=0)
p3 = ax.bar(ind + 2*width, greedy, width, bottom=0)
p4 = ax.bar(ind + 3*width, random, width, bottom=0)


# ax.set_title('Scalability Analysis')
ax.set_xticks(ind + 1.5*width)
ax.set_xticklabels(( 'Case 1', 'Case 2', 'Case 3')) #, '250'))
ax.tick_params(axis='x', labelsize=19)
ax.tick_params(axis='y', labelsize=19)


ax.legend((p1[0], p2[0], p3[0], p4[0]), ('DQN', 'MAD', 'greedy','random'), fontsize=20, loc='lower left')
# ax.legend(loc='best')
# plt.xlabel('Cases', fontsize=22)
plt.ylabel('Mean AoI at BS', fontsize=20)
plt.grid('True')

## /home/biplav/AoI/UAV_results/multi_UAV_Age_7/additional/exp9
